# %% [markdown]
# Create the pandas DataFrame from the provided student data.

# %%
# !pip install pandas
import pandas as pd
data = [
    {"StudentID":101, "Name":"Alice",   "Age":20, "Marks":88, "Grade":"A"},
    {"StudentID":102, "Name":"Bob",     "Age":21, "Marks":75, "Grade":"B"},
    {"StudentID":103, "Name":"Charlie", "Age":19, "Marks":92, "Grade":"A"},
    {"StudentID":104, "Name":"Diana",   "Age":22, "Marks":65, "Grade":"C"},
    {"StudentID":105, "Name":"Ethan",   "Age":20, "Marks":78, "Grade":"B"},
    {"StudentID":106, "Name":"Fiona",   "Age":21, "Marks":85, "Grade":"A"},
    {"StudentID":107, "Name":"George",  "Age":23, "Marks":70, "Grade":"B"},
    {"StudentID":108, "Name":"Hannah",  "Age":19, "Marks":95, "Grade":"A"},
    {"StudentID":109, "Name":"Ivan",    "Age":22, "Marks":60, "Grade":"C"},
    {"StudentID":110, "Name":"Julia",   "Age":20, "Marks":80, "Grade":"B"}
]
df = pd.DataFrame(data)
df
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 3.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.3/9.9 MB 4.2 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/9.9 MB 3.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.9/9.9 MB 3.9 MB/s eta 0:00:02
#    --------------- ------------------------ 3.9/9.9 MB 4.0 MB/s eta 0:00:02
#    ------------------- -------------------- 4.7/9.9 MB 4.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.5/9.9 MB 4.0 MB/s eta 0:00:02
#    ------------------------- -------------- 6.3/9.9 MB 3.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/9.9 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/9.9 MB 3.9 MB/s eta 0:00:01
# ...

# %% [markdown]
# Save the DataFrame as `students.csv`.

# %%
df.to_csv('students.csv', index=False)
print('Saved students.csv in the current notebook directory')
# Out:
# Saved students.csv in the current notebook directory

# %% [markdown]
# Reload `students.csv` into a new DataFrame.

# %%
df2 = pd.read_csv('students.csv')
df2
# Out:
#    StudentID     Name  Age  Marks Grade
# 0        101    Alice   20     88     A
# 1        102      Bob   21     75     B
# 2        103  Charlie   19     92     A
# 3        104    Diana   22     65     C
# 4        105    Ethan   20     78     B
# 5        106    Fiona   21     85     A
# 6        107   George   23     70     B
# 7        108   Hannah   19     95     A
# 8        109     Ivan   22     60     C
# 9        110    Julia   20     80     B

# %% [markdown]
# Display the first 3 rows using `df.head(3)`.

# %%
display(df2.head(3))
# Out:
#    StudentID     Name  Age  Marks Grade
# 0        101    Alice   20     88     A
# 1        102      Bob   21     75     B
# 2        103  Charlie   19     92     A

# %% [markdown]
# Display the statistical summary using `df.describe()`.

# %%
display(df2.describe(include='all'))
# Out:
#         StudentID   Name        Age      Marks Grade
# count    10.00000     10  10.000000  10.000000    10
# unique        NaN     10        NaN        NaN     3
# top           NaN  Alice        NaN        NaN     A
# freq          NaN      1        NaN        NaN     4
# mean    105.50000    NaN  20.700000  78.800000   NaN
# std       3.02765    NaN   1.337494  11.535453   NaN
# min     101.00000    NaN  19.000000  60.000000   NaN
# 25%     103.25000    NaN  20.000000  71.250000   NaN
# 50%     105.50000    NaN  20.500000  79.000000   NaN
# 75%     107.75000    NaN  21.750000  87.250000   NaN
# max     110.00000    NaN  23.000000  95.000000   NaN

# %% [markdown]
# Explore the data shape, dtypes, and info using `df.shape`, `df.dtypes`, and `df.info()`.

# %%
print('Shape:', df2.shape)
print('\nData types:\n', df2.dtypes)
print('\nInfo:')
df2.info()
# Out:
# Shape: (10, 5)
#
# Data types:
#  StudentID    int64
# Name           str
# Age          int64
# Marks        int64
# Grade          str
# dtype: object
#
# Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   StudentID  10 non-null     int64
#  1   Name       10 non-null     str
#  2   Age        10 non-null     int64
#  3   Marks      10 non-null     int64
#  4   Grade      10 non-null     str
# dtypes: int64(3), str(2)
# memory usage: 532.0 bytes
